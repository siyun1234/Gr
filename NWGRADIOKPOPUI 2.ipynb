# %% [markdown]
# # Restarting? Run this First to clear all files (ALL FILES AND MODELS WILL BE LOST!!!)

# %%
from IPython.display import clear_output
message = "Cleaned All Files"

# %cd /notebooks
# !rm -r Rproject

clear_output()
print(message)
# Out:
# Cleaned All Files

# %% [markdown]
# # Install All Things

# %%
from IPython.display import clear_output
next_message = "Step successfully completed, continuing to the next step"
message = "Installed KPOPEASYGUI, GUI is ready!"

# %cd /notebooks
# !git clone https://github.com/W1nOfGood/Rproject.git
clear_output()
print(next_message)

# !pip install --upgrade lxml
# !wget https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.onnx -O /notebooks/Rproject/assets/rmvpe/rmvpe.onnx
# !cd Rproject && pip install -r requirements.txt && python download_files.py
# !pip install --upgrade --no-deps --force-reinstall torchcrepe # try to fix audio not found tobyte error on this version

clear_output()
print(message)
# Out:
# Installed KPOPEASYGUI, GUI is ready!

# %% [markdown]
# # RUN KPOPWEBUI

# %%
# %cd /notebooks/Rproject
# %load_ext tensorboard
# %tensorboard --logdir ./logs
# !python app.py --colab
# Out:
# /notebooks/Rproject
# 2023-10-06 21:43:35 | INFO | faiss.loader | Loading faiss with AVX2 support.
# 2023-10-06 21:43:35 | INFO | faiss.loader | Successfully loaded faiss with AVX2 support.
# Do not forget to choose a model.
# Do not forget to choose a model.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://c76e1ec5b590aef58b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1oKr2kX3f7JhrqPCWzZmXggqfFbGkTQ5h
#
# --2023-10-06 21:45:18--  https://huggingface.co/leeloli/rosiestrong/resolve/main/rosiestrong.zip
# ...
